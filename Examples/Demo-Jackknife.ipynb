# %% [markdown]
# Colormaps:
# * PiYG, PRGn, BrBG, Puor, RoGy, RoBu, RoYIBu, RoYIGn, Spectral, coolwarm, bwr, seismic

# %%
import ipypb
import logging
import warnings
import numpy as np
import matplotlib.pyplot as plt
from hdf5storage import loadmat

import torch
import radam
import torchaudio
import pytorch_lightning as pl

import dynamic_strf

device = torch.device('cuda:0')

logging.getLogger('radam').setLevel(logging.CRITICAL)
logging.getLogger('pytorch_lightning').setLevel(logging.CRITICAL)
logging.getLogger().setLevel(logging.CRITICAL)
warnings.simplefilter('ignore')

# %%
top_db = 70
out_sr = 100
freqbins = 64
x_noisy = []
for i in range(19):
    sound, in_sr = torchaudio.load(f'Data/Sounds/stim{i+1}.flac')
    spect = dynamic_strf.modeling.SpectrogramParser(
        in_sr, out_sr, freqbins, f_max=11025/2, normalize=False
    )(sound)
    x_noisy.append(spect)

y_noisy = []
path_fmt = 'Data/LIJ%s_data_TrainOn1If2Records.mat'
for subj_id in ['109', '110', '112', '113', '114', '120']:
    y_noisy.append(loadmat(path_fmt % subj_id)['noisy_resp'].squeeze(0))
y_noisy = [torch.cat([torch.from_numpy(y[i]) for y in y_noisy], dim=1) for i in range(19)]

for i in range(19):
    diff = len(x_noisy[i]) - len(y_noisy[i])
    if diff == 1:
        x_noisy[i] = x_noisy[i][:-1]
    elif diff > 1:
        raise RuntimeError(f'X and Y have different lengths for stim{i+1}!')
    
    x_noisy[i] = x_noisy[i][100:-50].float()
    y_noisy[i] = y_noisy[i][100:-50].float()

x_noisy = x_noisy[:-1]
y_noisy = y_noisy[:-1]

channels = y_noisy[0].shape[1]

# %%
def builder():
    return dynamic_strf.modeling.DeepEncoder(
        input_size=freqbins,
        hidden_size=128,
        channels=channels
    ).to(device)

dynamic_strf.modeling.fit_multiple(
    builder=builder,
    data=(x_noisy, y_noisy),
    crossval=True,
    jackknife=True,
    save_dir='output/5x128-jackknife-cv',
    batch_size=64,
    num_workers=4,
    gpus=1,
    precision=16,
    verbose=1
)

model = builder()

dynamic_strf.estimate.dSTRF_multiple(
    model=model,
    checkpoints='output/5x128-jackknife-cv',
    data=(x_noisy, y_noisy),
    crossval=True,
    jackknife=True,
    save_dir='output/5x128-jackknife-cv-dstrf',
    chunk_size=100,
    verbose=1
)

scores = dynamic_strf.modeling.test_multiple(
    modle=builder(),
    checkpoints='output/5x128-jackknife-cv',
    data=(x_noisy, y_noisy),
    crossval=True,
    jackknife=True,
    verbose=1
)

nonlin = dynamic_strf.estimate.nonlinearities(
    paths='output/5x128-jackknife-cv-dstrf',
    reduction='mean',
    verbose=0
)
# Out:
# Directory "output/5x128-jackknife-cv" already exists.
# Fitting model for leave out: [0, 1]... Skip.
# Fitting model for leave out: [0, 2]... Skip.
# Fitting model for leave out: [0, 3]... Skip.
# Fitting model for leave out: [0, 4]... Skip.
# Fitting model for leave out: [0, 5]... Skip.
# Fitting model for leave out: [0, 6]... Skip.
# Fitting model for leave out: [0, 7]... Skip.
# Fitting model for leave out: [0, 8]... Skip.
# Fitting model for leave out: [0, 9]... Skip.
# Fitting model for leave out: [0, 10]... Skip.
# Fitting model for leave out: [0, 11]... Skip.
# Fitting model for leave out: [0, 12]... Skip.
# Fitting model for leave out: [0, 13]... Skip.
# Fitting model for leave out: [0, 14]... Skip.
# Fitting model for leave out: [0, 15]... Skip.
# Fitting model for leave out: [0, 16]... Skip.
# Fitting model for leave out: [0, 17]... Skip.
# Fitting model for leave out: [1, 2]... Skip.
# Fitting model for leave out: [1, 3]... Skip.
# Fitting model for leave out: [1, 4]... Skip.
# Fitting model for leave out: [1, 5]... Skip.
# Fitting model for leave out: [1, 6]... Skip.
# Fitting model for leave out: [1, 7]... Skip.
# Fitting model for leave out: [1, 8]... Skip.
# Fitting model for leave out: [1, 9]... Skip.
# Fitting model for leave out: [1, 10]... Skip.
# Fitting model for leave out: [1, 11]... Skip.
# Fitting model for leave out: [1, 12]... Skip.
# Fitting model for leave out: [1, 13]... Skip.
# Fitting model for leave out: [1, 14]... Skip.
# Fitting model for leave out: [1, 15]... Skip.
# Fitting model for leave out: [1, 16]... Skip.
# Fitting model for leave out: [1, 17]... Skip.
# Fitting model for leave out: [2, 3]... Skip.
# Fitting model for leave out: [2, 4]... Skip.
# Fitting model for leave out: [2, 5]... Skip.
# Fitting model for leave out: [2, 6]... Skip.
# Fitting model for leave out: [2, 7]... Skip.
# Fitting model for leave out: [2, 8]... Skip.
# Fitting model for leave out: [2, 9]... Skip.
# Fitting model for leave out: [2, 10]... Skip.
# Fitting model for leave out: [2, 11]... Skip.
# Fitting model for leave out: [2, 12]... Skip.
# Fitting model for leave out: [2, 13]... Skip.
# Fitting model for leave out: [2, 14]... Skip.
# Fitting model for leave out: [2, 15]... Skip.
# Fitting model for leave out: [2, 16]... Skip.
# Fitting model for leave out: [2, 17]... Skip.
# Fitting model for leave out: [3, 4]... Skip.
# Fitting model for leave out: [3, 5]... Skip.
# Fitting model for leave out: [3, 6]... Skip.
# Fitting model for leave out: [3, 7]... Skip.
# Fitting model for leave out: [3, 8]... Skip.
# Fitting model for leave out: [3, 9]... Skip.
# Fitting model for leave out: [3, 10]... Skip.
# Fitting model for leave out: [3, 11]... Skip.
# Fitting model for leave out: [3, 12]... Skip.
# Fitting model for leave out: [3, 13]... Skip.
# Fitting model for leave out: [3, 14]... Skip.
# Fitting model for leave out: [3, 15]... Skip.
# Fitting model for leave out: [3, 16]... Skip.
# Fitting model for leave out: [3, 17]... Skip.
# Fitting model for leave out: [4, 5]... Skip.
# Fitting model for leave out: [4, 6]... Skip.
# Fitting model for leave out: [4, 7]... Skip.
# Fitting model for leave out: [4, 8]... Skip.
# Fitting model for leave out: [4, 9]... Skip.
# Fitting model for leave out: [4, 10]... Skip.
# Fitting model for leave out: [4, 11]... Skip.
# Fitting model for leave out: [4, 12]... Skip.
# Fitting model for leave out: [4, 13]... Skip.
# Fitting model for leave out: [4, 14]... Skip.
# Fitting model for leave out: [4, 15]... Skip.
# Fitting model for leave out: [4, 16]... Skip.
# Fitting model for leave out: [4, 17]... Skip.
# Fitting model for leave out: [5, 6]... Skip.
# Fitting model for leave out: [5, 7]... Skip.
# Fitting model for leave out: [5, 8]... Skip.
# Fitting model for leave out: [5, 9]... Skip.
# Fitting model for leave out: [5, 10]... Skip.
# Fitting model for leave out: [5, 11]... Skip.
# Fitting model for leave out: [5, 12]... Skip.
# Fitting model for leave out: [5, 13]... Skip.
# Fitting model for leave out: [5, 14]... Skip.
# Fitting model for leave out: [5, 15]... Skip.
# Fitting model for leave out: [5, 16]... Skip.
# Fitting model for leave out: [5, 17]... Skip.
# Fitting model for leave out: [6, 7]... Skip.
# Fitting model for leave out: [6, 8]... Skip.
# Fitting model for leave out: [6, 9]... Skip.
# Fitting model for leave out: [6, 10]... Skip.
# Fitting model for leave out: [6, 11]... Skip.
# Fitting model for leave out: [6, 12]... Skip.
# Fitting model for leave out: [6, 13]... Skip.
# Fitting model for leave out: [6, 14]... Skip.
# Fitting model for leave out: [6, 15]... Skip.
# Fitting model for leave out: [6, 16]... Skip.
# Fitting model for leave out: [6, 17]... Skip.
# Fitting model for leave out: [7, 8]... Skip.
# Fitting model for leave out: [7, 9]... Skip.
# Fitting model for leave out: [7, 10]... Skip.
# Fitting model for leave out: [7, 11]... Skip.
# Fitting model for leave out: [7, 12]... Skip.
# Fitting model for leave out: [7, 13]... Skip.
# Fitting model for leave out: [7, 14]... Skip.
# Fitting model for leave out: [7, 15]... Skip.
# Fitting model for leave out: [7, 16]... Skip.
# Fitting model for leave out: [7, 17]... Skip.
# Fitting model for leave out: [8, 9]... Skip.
# Fitting model for leave out: [8, 10]... Skip.
# Fitting model for leave out: [8, 11]... Skip.
# Fitting model for leave out: [8, 12]... Done.
# Fitting model for leave out: [8, 13]... Done.
# Fitting model for leave out: [8, 14]... Done.
# Fitting model for leave out: [8, 15]...
